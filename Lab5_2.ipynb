# %%
import pandas as pd
import numpy as np
dane1 = pd.read_csv("dane.csv", header=None, na_values='?')

dane1.columns = ["pclass","survived","name","sex","age","sibsp","parch","ticket","fare","cabin","embarked","boat","body","home.dest"]
col = ["pclass","survived","name","sex","ticket","cabin","embarked","boat","body","home.dest"]

for i in col:
  print('Liczba etykiet zmiennej '+ i + ' {}'.format(len(dane1.loc[:,i].unique())))

print("\nliczba wszystkich imion" + ' {}'.format(len(dane1.loc[:,"name"])))

list_cab = dane1.loc[:,"cabin"].unique()

print("\nliczba unikalnych kabin" + ' {}'.format(len(list_cab)))

dane1["CabinReduced"] = dane1["cabin"].astype(str).str[0]

print("\nliczba unikalnych zredukowanych kabin" + ' {}'.format(len(dane1.loc[:,"CabinReduced"].unique())))

print("Zredukowano o " + str(round(100 - 9/187*100,2)) + "% kardynalnosc zbioru zmiennej opisujacej kabiny")
dane1.head(20)
# Out:
# Liczba etykiet zmiennej pclass 3
# Liczba etykiet zmiennej survived 2
# Liczba etykiet zmiennej name 1307
# Liczba etykiet zmiennej sex 2
# Liczba etykiet zmiennej ticket 929
# Liczba etykiet zmiennej cabin 187
# Liczba etykiet zmiennej embarked 4
# Liczba etykiet zmiennej boat 28
# Liczba etykiet zmiennej body 122
# Liczba etykiet zmiennej home.dest 370
#
# liczba wszystkich imion 1309
#
# liczba unikalnych kabin 187
#
# liczba unikalnych zredukowanych kabin 9
# Zredukowano o 95.19% kardynalnosc zbioru zmiennej opisujacej kabiny
#     pclass  survived                                               name  \
# 0        1         1                      Allen, Miss. Elisabeth Walton
# 1        1         1                     Allison, Master. Hudson Trevor
# 2        1         0                       Allison, Miss. Helen Loraine
# 3        1         0               Allison, Mr. Hudson Joshua Creighton
# 4        1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...

# %% [markdown]
# Liczba unikalnych imion pasazerow rozni sie od liczby wszystkich pasazerow o 2
#
# Duża moc zbioru:
#
# name: 1307
# ticket: 929
# cabin: 187
# body: 122
# home.dest: 370
#
# Mała moc zbioru:
#
# pclass: 3
# survived: 2
# sex: 2
# embarked: 4
# boat: 28
#
# Redukujemy akurat te zmienna poniewaz nie chcemy tak dokladnie analizowac tej cechy wystarczy nam wiedza w ktorej czesci statku znajdowala sie dana kabina do czego wystraczy nam pierwsza litera
#
# Upraszcza to przyszle analizy
#
# Moze powodowac pewne male niescislosci
